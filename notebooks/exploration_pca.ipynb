# %% [markdown]
# # Démonstration : Reconnaissance Faciale par PCA
#
# Ce notebook présente les étapes clés pour utiliser le système de reconnaissance faciale.

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

import matplotlib.pyplot as plt
from src.preprocessing import load_images_from_folder
from src.pca_model import FacePCAModel
print("Modules importés avec succès.")

# %% [markdown]
# ## 1. Visualisation des données
#
# Placez des images dans `../data/raw/` pour les voir ici.

# %%
DATA_PATH = "../data/raw"
if os.path.exists(DATA_PATH) and os.listdir(DATA_PATH):
    images, labels, _ = load_images_from_folder(DATA_PATH)
    plt.imshow(images[0].reshape(100, 100), cmap='gray')
    plt.title(f"Label: {labels[0]}")
    plt.show()
else:
    print("Dossier vide. Veuillez ajouter des images dans data/raw.")
